# %% [markdown]
# # ISLR - Chapter 2 - (Exercises/Applied/Question 8)

# %% [markdown]
# <font color='green'>
# **An Introduction to Statistical Learning with Applications in R**
#
# Chapter 2 - 2.4 Exercises/Applied bölümünde [College.csv](https://book.huihoo.com/introduction-to-statistical-learning/data.html) verisini kullanarak 8.soruyu cevaplandırdım. Daha sonrasında Data Exploring ve Data Visualization işlemleri gerçekleştirdim.
# </font>

# %% [markdown]
# **8.** *This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are:*

# %% [markdown]
# - **Private** : Public/private indicator *(kamu/özel göstergesi)*
# - **Apps** : Number of applications received
# - **Accept** : Number of applicants accepted
# - **Enroll** : Number of new students enrolled
# - **Top10perc** : New students from top 10% of high school class
# - **Top25perc** : New students from top 25% of high school class
# - **F.Undergrad** : Number of full-time undergraduates
# - **P.Undergrad** : Number of part-time undergraduates
# - **Outstate** : Out-of-state tuition *(Eyalet dışı öğrenim ücreti, uluslararası öğrenciler de dahil olmak üzere eyalet dışından gelen öğrencilerin bir devlet okuluna gitmek için ödediği bedeli ifade eder.)*
# - **Room.Board** : Room and board costs *(oda ve yemek masrafları)*
# - **Books** : Estimated book costs
# - **Personal** : Estimated personal spending
# - **PhD** : Percent of faculty with Ph.D.’s *(doktora derecesine sahip öğretim üyelerinin yüzdesi)*
# - **Terminal** : Percent of faculty with terminal degree
# - **S.F.Ratio** : Student/faculty ratio *(öğrenci/öğretim üyesi oranı)*
# - **perc.alumni** : Percent of alumni who donate *(bağış yapan mezunların yüzdesi)*
# - **Expend** : Instructional expenditure per student *(öğrenci başına eğitim harcaması)*
# - **Grad.Rate** : Graduation rate

# %% [markdown]
# ## **(a)**
# *Use the read.csv() function to read the data into R. Call the loaded data as college. Make sure that you have the directory set to the correct location for the data.*

# %%
import pandas as pd

# %%
college = pd.read_csv("College.csv")

# %% [markdown]
# ## **(b)**
# *Look at the data using the View() function. You should notice that the first column is just the name of each university. We don’t really want R to treat this as data. However, it may be handy to have these names for later.*

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# *You should see that there is now a row.names column with the name of each university recorded. This means that R has given each row a name corresponding to the appropriate university. R will not try to perform calculations on the row names. However, we still need to eliminate the first column in the data where the names are stored.*

# %%
college = college.set_index('Unnamed: 0')
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Unnamed: 0
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# *Now you should see that the first data column is Private. Note
# that another column labeled rownames now appears before the Private column. However, this is not a data column but rather the name that R is giving to each row.*

# %% [markdown]
# ## **(c)**

# %% [markdown]
# **i.** *Use the summary() function to produce a numerical summary of the variables in the data set.*

# %%
college.describe().T
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         777.0   3001.638353  3870.201484    81.0   776.0  1558.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       777.0    779.972973   929.176190    35.0   242.0   434.0
# Top10perc    777.0     27.558559    17.640364     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    549.380952   165.105360    96.0   470.0   500.0
# Personal     777.0   1340.642214   677.071454   250.0   850.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# ...

# %% [markdown]
# **ii.** *Use the pairs() function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that you can reference the first ten columns of a matrix A using A[,1:10].*

# %%
college.columns[0:10]
# Out:
# Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#        'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board'],
#       dtype='object')

# %%
college[college.columns[0:10]]
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
# ...

# %%
data = college[college.columns[0:10]]
data
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
# ...

# %%
import seaborn as sns

sns.set(style="ticks")
sns.pairplot(data, kind="reg");

# %% [markdown]
# It can also be done this way using scatter_matrix.

# %%
import numpy as np 
import pandas as pd
from pandas.plotting import scatter_matrix

scatter_matrix(data, alpha=0.5, figsize=(20, 20));

# %% [markdown]
# **iii.** *Use the plot() function to produce side-by-side boxplots of Outstate versus Private.*

# %%
ax = sns.boxplot(x="Private", y="Outstate", data=df, palette="Set3")

# %% [markdown]
# **iv.** *Create a new qualitative variable, called Elite, by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50 %.*

# %%
college["Top10perc"].values>50
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False, False,
# ...

# %%
college[college["Top10perc"].values>50]
# Out:
#                             Private   Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Agnes Scott College             Yes    417     349     137         60
# Amherst College                 Yes   4302     992     418         83
# Barnard College                 Yes   2496    1402     531         53
# Birmingham-Southern College     Yes    805     588     287         67
# Bowdoin College                 Yes   3356    1019     418         76
# ...                             ...    ...     ...     ...        ...
# Wesleyan University             Yes   4772    1973     712         60
# Wheaton College IL              Yes   1432     920     548         56
# Williams College                Yes   4186    1245     526         81
# Wofford College                 Yes   1501     935     273         51
# Yale University                 Yes  10705    2453    1317         95
#
#                              Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Unnamed: 0
# ...

# %%
college["Elite"] = False

# %%
college.loc[college['Top10perc'].values>50,'Elite'] = True

# %% [markdown]
# *Use the summary() function to see how many elite universities there are. Now use the plot() function to produce side-by-side boxplots of Outstate versus Elite.*

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Unnamed: 0
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Unnamed: 0
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
len(college[college["Elite"]] == True)
# Out:
# 78

# %%
college["Elite"].value_counts()
# Out:
# False    699
# True      78
# Name: Elite, dtype: int64

# %%
ax = sns.boxplot(x="Elite", y="Outstate", data=college, palette="Set3")

# %% [markdown]
# **v.** *Use the hist() function to produce some histograms with differing numbers of bins for a few of the quantitative variables. You may find the command par(mfrow = c(2, 2)) useful: it will divide the print window into four regions so that four plots can be made simultaneously. Modifying the arguments to this function will divide the screen in other ways.*

# %%
df.hist(['Room.Board','Books', 'Personal', 'Expend' ],bins=50, figsize=(10,6));

# %% [markdown]
# ## **(c) vi.**
# *Continue exploring the data, and provide a brief summary of what you discover.*

# %% [markdown]
# ### Loading Data

# %%
import pandas as pd

# %%
college = pd.read_csv("College.csv")

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %% [markdown]
# ### Data Exploring

# %% [markdown]
# #### <font color='green'> **Sütun adlarını değiştirdim.**</font>

# %%
data = college.copy()

# %%
data.rename(columns = {'Unnamed: 0' : 'Üniversite','Private' : 'Özel', 'Apps' : 'Başvuru', 'Accept' : 'Kabul Edilen', 
                     'Enroll' : 'Kaydolan', 'Top10perc' : '%10luk Dilimden', 
                     'Top25perc' : '%25lik Dilimden', 'F.Undergrad' : 'Tam Zamanlı',
                     'P.Undergrad' : 'Yarı Zamanlı','Outstate' : 'Eyalet Dışı Öğrenim Ücreti', 
                     'Room.Board' : 'Konaklama ve Yemek Masrafları', 'Books' : 'Tahmini Kitap Maliyeti', 
                     'Personal' : 'Tahmini Kişisel Harcama','PhD' : 'Phd Ö.G Yüzd.', 'Terminal' : 'Terminal Ö.G Yüzd.',
                     'S.F.Ratio' : 'Öğrenci/Ö.G','perc.alumni' : 'Bağış Yüzd.',
                    'Expend' : 'Öğrenci Başına Harcama', 'Grad.Rate' : 'Mezuniyet Derecesi'}, inplace = True)

# %%
data.head()
# Out:
#                      Üniversite Özel  Başvuru  Kabul Edilen  Kaydolan  \
# 0  Abilene Christian University  Yes     1660          1232       721
# 1            Adelphi University  Yes     2186          1924       512
# 2                Adrian College  Yes     1428          1097       336
# 3           Agnes Scott College  Yes      417           349       137
# 4     Alaska Pacific University  Yes      193           146        55
#
#    %10luk Dilimden  %25lik Dilimden  Tam Zamanlı  Yarı Zamanlı  \
# 0               23               52         2885           537
# 1               16               29         2683          1227
# 2               22               50         1036            99
# 3               60               89          510            63
# 4               16               44          249           869
#
#    Eyalet Dışı Öğrenim Ücreti  Konaklama ve Yemek Masrafları  \
# 0                        7440                           3300
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Üniversite                     777 non-null    object
#  1   Özel                           777 non-null    object
#  2   Başvuru                        777 non-null    int64
#  3   Kabul Edilen                   777 non-null    int64
#  4   Kaydolan                       777 non-null    int64
#  5   %10luk Dilimden                777 non-null    int64
#  6   %25lik Dilimden                777 non-null    int64
#  7   Tam Zamanlı                    777 non-null    int64
#  8   Yarı Zamanlı                   777 non-null    int64
#  9   Eyalet Dışı Öğrenim Ücreti     777 non-null    int64
#  10  Konaklama ve Yemek Masrafları  777 non-null    int64
#  11  Tahmini Kitap Maliyeti         777 non-null    int64
# ...

# %% [markdown]
# #### <font color='green'> Daha sonra kullanacağım fonksiyonlarda sıkıntı çıkarmaması için object değişkenleri category tipine dönüştürüyorum.</font>

# %% [markdown]
# **Object veri tipinde olanları listeliyorum.**

# %%
data.select_dtypes(include = ["object"]).columns
# Out:
# Index(['Üniversite', 'Özel'], dtype='object')

# %%
data["Üniversite"] = pd.Categorical(data["Üniversite"])
data["Özel"] = pd.Categorical(data["Özel"])

# %%
data.dtypes
# Out:
# Üniversite                       category
# Özel                             category
# Başvuru                             int64
# Kabul Edilen                        int64
# Kaydolan                            int64
# %10luk Dilimden                     int64
# %25lik Dilimden                     int64
# Tam Zamanlı                         int64
# Yarı Zamanlı                        int64
# Eyalet Dışı Öğrenim Ücreti          int64
# Konaklama ve Yemek Masrafları       int64
# Tahmini Kitap Maliyeti              int64
# Tahmini Kişisel Harcama             int64
# Phd Ö.G Yüzd.                       int64
# Terminal Ö.G Yüzd.                  int64
# Öğrenci/Ö.G                       float64
# Bağış Yüzd.                         int64
# Öğrenci Başına Harcama              int64
# Mezuniyet Derecesi                  int64
# dtype: object

# %%
data["Üniversite"].dtypes
# Out:
# CategoricalDtype(categories=['Abilene Christian University', 'Adelphi University',
#                   'Adrian College', 'Agnes Scott College',
#                   'Alaska Pacific University', 'Albertson College',
#                   'Albertus Magnus College', 'Albion College',
#                   'Albright College', 'Alderson-Broaddus College',
#                   ...
#                   'Winthrop University', 'Wisconsin Lutheran College',
#                   'Wittenberg University', 'Wofford College',
#                   'Worcester Polytechnic Institute', 'Worcester State College',
#                   'Xavier University', 'Xavier University of Louisiana',
#                   'Yale University', 'York College of Pennsylvania'],
#                  ordered=False)

# %%
data["Özel"].dtypes
# Out:
# CategoricalDtype(categories=['No', 'Yes'], ordered=False)

# %%
data["Üniversite"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Abilene Christian University
# 1                  Adelphi University
# 2                      Adrian College
# 3                 Agnes Scott College
# 4           Alaska Pacific University
#                     ...
# 772           Worcester State College
# 773                 Xavier University
# 774    Xavier University of Louisiana
# 775                   Yale University
# 776      York College of Pennsylvania
# Name: Üniversite, Length: 777, dtype: category
# Categories (777, object): [Abilene Christian University, Adelphi University, Adrian College, Agnes Scott College, ..., Xavier University, Xavier University of Louisiana, Yale University, York College of Pennsylvania]>

# %% [markdown]
# #### <font color='green'> Üniversite 777 adet, bizim datasetimizin boyutunda. Yani Üniversite sütunundaki tüm değerler unique. Bu sütunu index yapıyorum bu yüzden.</font>

# %%
df = data.set_index("Üniversite")

# %%
df.head()
# Out:
#                              Özel  Başvuru  Kabul Edilen  Kaydolan  \
# Üniversite
# Abilene Christian University  Yes     1660          1232       721
# Adelphi University            Yes     2186          1924       512
# Adrian College                Yes     1428          1097       336
# Agnes Scott College           Yes      417           349       137
# Alaska Pacific University     Yes      193           146        55
#
#                               %10luk Dilimden  %25lik Dilimden  Tam Zamanlı  \
# Üniversite
# Abilene Christian University               23               52         2885
# Adelphi University                         16               29         2683
# Adrian College                             22               50         1036
# Agnes Scott College                        60               89          510
# Alaska Pacific University                  16               44          249
#
#                               Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# ...

# %% [markdown]
# ### Data Visualizing

# %% [markdown]
# #### <font color='green'> 1. Kaç devlet üniversitesi kaç özel üniversite var grafik üzerinde gösterdim.</font>

# %%
df["Özel"].value_counts()
# Out:
# Yes    565
# No     212
# Name: Özel, dtype: int64

# %%
ax = sns.countplot(x='Özel', data=df, palette="Set1");
plt.show()

# %% [markdown]
# #### <font color='green'> 2. Devlet üniversitelerindeki ve özel üniversitelerde başvuran-kabul edilen-kayıt olanların barplot üzerinde gösterilmesi </font>

# %% [markdown]
# [Buradan](https://www.delftstack.com/howto/matplotlib/pandas-plot-multiple-columns-on-bar-chart-matplotlib/) yararlandım.

# %% [markdown]
# *Bunu direkt uygulayamıyorum çünkü x kısmı birbirinden farklı değerler içeren bir series olmalı.*
#
# `sns.barplot(x = "Özel", y = ["Başvuru","Kabul Edilen","Kaydolan"], data = df);`

# %%
filtre = df.groupby(["Özel"])

# %%
df_filtre = filtre.mean()

# %%
df_filtre
# Out:
#           Başvuru  Kabul Edilen     Kaydolan  %10luk Dilimden  \
# Özel
# No    5729.919811   3919.287736  1640.872642        22.834906
# Yes   1977.929204   1305.702655   456.945133        29.330973
#
#       %25lik Dilimden  Tam Zamanlı  Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# Özel
# No          52.702830  8571.004717   1978.188679                 6813.410377
# Yes         56.957522  1872.168142    433.966372                11801.693805
#
#       Konaklama ve Yemek Masrafları  Tahmini Kitap Maliyeti  \
# Özel
# No                      3748.240566              554.377358
# Yes                     4586.143363              547.506195
#
#       Tahmini Kişisel Harcama  Phd Ö.G Yüzd.  Terminal Ö.G Yüzd.  Öğrenci/Ö.G  \
# Özel
# No                1676.981132      76.834906           82.816038    17.139151
# Yes               1214.440708      71.093805           78.534513    12.945487
#
#       Bağış Yüzd.  Öğrenci Başına Harcama  Mezuniyet Derecesi
# Özel
# ...

# %%
df_filtre = df_filtre.reset_index()
df_filtre
# Out:
#   Özel      Başvuru  Kabul Edilen     Kaydolan  %10luk Dilimden  \
# 0   No  5729.919811   3919.287736  1640.872642        22.834906
# 1  Yes  1977.929204   1305.702655   456.945133        29.330973
#
#    %25lik Dilimden  Tam Zamanlı  Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# 0        52.702830  8571.004717   1978.188679                 6813.410377
# 1        56.957522  1872.168142    433.966372                11801.693805
#
#    Konaklama ve Yemek Masrafları  Tahmini Kitap Maliyeti  \
# 0                    3748.240566              554.377358
# 1                    4586.143363              547.506195
#
#    Tahmini Kişisel Harcama  Phd Ö.G Yüzd.  Terminal Ö.G Yüzd.  Öğrenci/Ö.G  \
# 0              1676.981132      76.834906           82.816038    17.139151
# 1              1214.440708      71.093805           78.534513    12.945487
#
#    Bağış Yüzd.  Öğrenci Başına Harcama  Mezuniyet Derecesi
# 0    14.358491             7458.316038           56.042453
# ...

# %%
df_filtre.plot(x = "Özel", y = ["Başvuru","Kabul Edilen","Kaydolan"], kind="bar",figsize=(9,8))
plt.show()

# %% [markdown]
# #### <font color='green'> 3. Okula yapılan toplam masrafla mezuniyet derecesi arasında bir ilişki var mı?</font>

# %%
df["Toplam Masraf"] = df["Eyalet Dışı Öğrenim Ücreti"]+df["Konaklama ve Yemek Masrafları"]+df["Tahmini Kitap Maliyeti"]+df["Tahmini Kişisel Harcama"]

# %%
df.head()
# Out:
#                              Özel  Başvuru  Kabul Edilen  Kaydolan  \
# Üniversite
# Abilene Christian University  Yes     1660          1232       721
# Adelphi University            Yes     2186          1924       512
# Adrian College                Yes     1428          1097       336
# Agnes Scott College           Yes      417           349       137
# Alaska Pacific University     Yes      193           146        55
#
#                               %10luk Dilimden  %25lik Dilimden  Tam Zamanlı  \
# Üniversite
# Abilene Christian University               23               52         2885
# Adelphi University                         16               29         2683
# Adrian College                             22               50         1036
# Agnes Scott College                        60               89          510
# Alaska Pacific University                  16               44          249
#
#                               Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# ...

# %%
import matplotlib.pyplot as plt
g = sns.regplot(df["Mezuniyet Derecesi"],df["Toplam Masraf"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_xlabel("Mezuniyet Derecesi")
g.set_ylabel("Toplam Masraf")
plt.xlim(0,100)
plt.ylim(bottom=0);

# %% [markdown]
# Mezuniyet derecesiyle okula yapılan toplam harcama arasında doğrusal bir ilişki var.

# %%
df.hist(['Toplam Masraf' ],bins=50, figsize=(6,6));

# %% [markdown]
# #### <font color='green'> 4. İlk %10'dan gelenlerin oranı %50'den fazlaysa Elite olarak isimlendirdim ve bu okulların yapılan toplam masrafla ilişkisine baktım.</font>

# %%
df["Elite"] = False
df.loc[df['%10luk Dilimden'].values>50,'Elite'] = True

# %%
df.head()
# Out:
#                              Özel  Başvuru  Kabul Edilen  Kaydolan  \
# Üniversite
# Abilene Christian University  Yes     1660          1232       721
# Adelphi University            Yes     2186          1924       512
# Adrian College                Yes     1428          1097       336
# Agnes Scott College           Yes      417           349       137
# Alaska Pacific University     Yes      193           146        55
#
#                               %10luk Dilimden  %25lik Dilimden  Tam Zamanlı  \
# Üniversite
# Abilene Christian University               23               52         2885
# Adelphi University                         16               29         2683
# Adrian College                             22               50         1036
# Agnes Scott College                        60               89          510
# Alaska Pacific University                  16               44          249
#
#                               Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# ...

# %%
g = sns.regplot(df["Mezuniyet Derecesi"],df["Toplam Masraf"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_xlabel("Mezuniyet Derecesi")
g.set_ylabel("Toplam Masraf")
plt.xlim(0,100)
plt.ylim(bottom=0);

# %%
ax = sns.boxplot(x="Elite", y="Toplam Masraf", data=df, palette="Set3")

# %% [markdown]
# %10'luk dilimden gelen öğrencilerin %50 ve üzeri olduğu okullar için yapılan toplam masraf, olmayanlardan daha fazla.

# %% [markdown]
# #### <font color='green'> 5. Okullara kabul edilme oranıyla elite'lik arasında bir ilişki var mı diye baktım.</font>

# %%
df['Kabul Oranı'] = df["Kabul Edilen"]/df["Başvuru"]

# %%
df.head()
# Out:
#                              Özel  Başvuru  Kabul Edilen  Kaydolan  \
# Üniversite
# Abilene Christian University  Yes     1660          1232       721
# Adelphi University            Yes     2186          1924       512
# Adrian College                Yes     1428          1097       336
# Agnes Scott College           Yes      417           349       137
# Alaska Pacific University     Yes      193           146        55
#
#                               %10luk Dilimden  %25lik Dilimden  Tam Zamanlı  \
# Üniversite
# Abilene Christian University               23               52         2885
# Adelphi University                         16               29         2683
# Adrian College                             22               50         1036
# Agnes Scott College                        60               89          510
# Alaska Pacific University                  16               44          249
#
#                               Yarı Zamanlı  Eyalet Dışı Öğrenim Ücreti  \
# ...

# %%
ax = sns.boxplot(x="Elite", y="Kabul Oranı", data=df, palette="Set3")

# %% [markdown]
# Elite olan okulların öğrencileri kabul etme oranı çok daha düşük.
